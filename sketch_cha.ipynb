# %%
import matplotlib.pyplot as plt

# %%
import numpy as nmp

# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)
df.tail()
# Out:
#                Timestamp Kategori Anda Kategori Umur Anda  \
# 971   10/4/2019 15:38:56        Alumni            > 40 th
# 972    10/7/2019 9:04:03     Mahasiswa            < 25 th
# 973    10/8/2019 8:52:14         Dosen         25 - 40 th
# 974   10/8/2019 11:45:04        Alumni         25 - 40 th
# 975  10/14/2019 13:50:34        Alumni            < 25 th
#
#                           CaRek Pilihan  \
# 971      I Nyoman Pugeg Aryantha (SITH)
# 972          Edy Tri Baskoro (FMIPA-MA)
# 973      Ary Setiaji Prihatmanto (STEI)
# 974      Ary Setiaji Prihatmanto (STEI)
# 975  Gusti Ayu Putri Saptawati S (STEI)
#
#                              Alasan Memilih CaRek  \
# 971        Emansipasi, kesetaraan dan kebhinekaan
# 972                           Alumni SMPP Jombang
# 973  Kapabilitas ybs utk meningkatkan ranking ITB
# 974                       Akhlak dan budi pekerti
# 975  Sesuai dengan kriteria kekinian (Rektor 4.0)
#
#                                           Harapan Anda
# ...

# %%
df[df['CaRek Pilihan'] == 'Sigit Puji Santosa (FTMD)'].head()
# Out:
#              Timestamp Kategori Anda Kategori Umur Anda  \
# 78   9/1/2019 16:11:39        Alumni         25 - 40 th
# 115  9/1/2019 17:54:55        Alumni            > 40 th
# 145  9/1/2019 19:12:41         Dosen            > 40 th
# 175  9/1/2019 21:20:14         Dosen            > 40 th
# 179  9/1/2019 21:35:21        Alumni            > 40 th
#
#                  CaRek Pilihan  \
# 78   Sigit Puji Santosa (FTMD)
# 115  Sigit Puji Santosa (FTMD)
# 145  Sigit Puji Santosa (FTMD)
# 175  Sigit Puji Santosa (FTMD)
# 179  Sigit Puji Santosa (FTMD)
#
#                                   Alasan Memilih CaRek  \
# 78        Sesuai dengan kriteria kekinian (Rektor 4.0)
# 115  Kapabilitas ybs utk memajukan riset dan indust...
# 145       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 175       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 179  Kapabilitas ybs utk memajukan riset dan indust...
#
#                                           Harapan Anda
# ...

# %%
df[df['CaRek Pilihan'] == 'Sigit Puji Santosa (FTMD)'].sum()
# Out:
# Timestamp               9/1/2019 16:11:399/1/2019 17:54:559/1/2019 19:...
# Kategori Anda           AlumniAlumniDosenDosenAlumniAlumniAlumniAlumni...
# Kategori Umur Anda      25 - 40 th> 40 th> 40 th> 40 th> 40 th> 40 th>...
# CaRek Pilihan           Sigit Puji Santosa (FTMD)Sigit Puji Santosa (F...
# Alasan Memilih CaRek    Sesuai dengan kriteria kekinian (Rektor 4.0)Ka...
# dtype: object

# %%
df[df['CaRek Pilihan'] == 'Sigit Puji Santosa (FTMD)']['Kategori Anda']
# Out:
# 78        Alumni
# 115       Alumni
# 145        Dosen
# 175        Dosen
# 179       Alumni
# 183       Alumni
# 189       Alumni
# 190       Alumni
# 199       Alumni
# 201       Alumni
# 202       Alumni
# 223        Dosen
# 239       Alumni
# 259         Umum
# 355       Alumni
# 460       Alumni
# 483       Alumni
# 716        Dosen
# 718    Mahasiswa
# 719    Mahasiswa
# 722    Mahasiswa
# 729       Alumni
# 749       Alumni
# 921        Dosen
# 949        Dosen
# Name: Kategori Anda, dtype: object

# %%
Pilihan1= df[df['CaRek Pilihan'] == 'Sigit Puji Santosa (FTMD)']

# %%
arr1 = nmp.array(Pilihan1['Kategori Anda'])

# %%
Pilihan1
# Out:
#               Timestamp Kategori Anda Kategori Umur Anda  \
# 78    9/1/2019 16:11:39        Alumni         25 - 40 th
# 115   9/1/2019 17:54:55        Alumni            > 40 th
# 145   9/1/2019 19:12:41         Dosen            > 40 th
# 175   9/1/2019 21:20:14         Dosen            > 40 th
# 179   9/1/2019 21:35:21        Alumni            > 40 th
# 183   9/1/2019 21:41:45        Alumni            > 40 th
# 189   9/1/2019 21:56:14        Alumni            > 40 th
# 190   9/1/2019 22:00:07        Alumni            > 40 th
# 199   9/1/2019 22:42:06        Alumni            > 40 th
# 201   9/1/2019 22:46:34        Alumni            > 40 th
# 202   9/1/2019 22:46:58        Alumni            > 40 th
# 223    9/2/2019 6:55:54         Dosen            > 40 th
# 239    9/2/2019 8:49:46        Alumni            > 40 th
# 259   9/2/2019 12:43:19          Umum            > 40 th
# 355    9/3/2019 0:32:43        Alumni            > 40 th
# ...

# %%
ax = df['Kategori Anda'].value_counts()
ax
# Out:
# Alumni              342
# Umum                270
# Mahasiswa           166
# Dosen               138
# Pegawai / Tendik     60
# Name: Kategori Anda, dtype: int64

# %%
Pilihan1.sum()
# Out:
# Timestamp               9/1/2019 16:11:399/1/2019 17:54:559/1/2019 19:...
# Kategori Anda           AlumniAlumniDosenDosenAlumniAlumniAlumniAlumni...
# Kategori Umur Anda      25 - 40 th> 40 th> 40 th> 40 th> 40 th> 40 th>...
# CaRek Pilihan           Sigit Puji Santosa (FTMD)Sigit Puji Santosa (F...
# Alasan Memilih CaRek    Sesuai dengan kriteria kekinian (Rektor 4.0)Ka...
# dtype: object

# %%
Pilihan1['Kategori Anda']
# Out:
# 78        Alumni
# 115       Alumni
# 145        Dosen
# 175        Dosen
# 179       Alumni
# 183       Alumni
# 189       Alumni
# 190       Alumni
# 199       Alumni
# 201       Alumni
# 202       Alumni
# 223        Dosen
# 239       Alumni
# 259         Umum
# 355       Alumni
# 460       Alumni
# 483       Alumni
# 716        Dosen
# 718    Mahasiswa
# 719    Mahasiswa
# 722    Mahasiswa
# 729       Alumni
# 749       Alumni
# 921        Dosen
# 949        Dosen
# Name: Kategori Anda, dtype: object

# %%
df['Kategori Anda']
# Out:
# 0                Alumni
# 1                Alumni
# 2                  Umum
# 3      Pegawai / Tendik
# 4                 Dosen
#              ...
# 971              Alumni
# 972           Mahasiswa
# 973               Dosen
# 974              Alumni
# 975              Alumni
# Name: Kategori Anda, Length: 976, dtype: object

# %%
len(Pilihan1['Kategori Anda'])
# Out:
# 25

# %%
arr2=Pilihan1['Kategori Anda']

# %%
arr2.value_counts().sum()
# Out:
# 25

# %%
ax = arr2.value_counts().plot(kind='bar')

# %%
Pilihan1.sort('Timestamp')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-40216c404746> in <module>
# ----> 1 Pilihan1.sort('Timestamp')
#
# c:\users\thirza\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
Pilihan1.to_datetime(df.Date).order().index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-acc4a860b6f0> in <module>
# ----> 1 Pilihan1.to_datetime(df.Date).order().index
#
# c:\users\thirza\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_datetime'

# %%
Pilihan1.sort_values(by=('Timestamp')).tail()
# Out:
#              Timestamp Kategori Anda Kategori Umur Anda  \
# 716  9/8/2019 18:32:06         Dosen         25 - 40 th
# 718  9/8/2019 19:26:08     Mahasiswa            < 25 th
# 719  9/8/2019 23:14:35     Mahasiswa         25 - 40 th
# 722  9/9/2019 11:23:27     Mahasiswa            < 25 th
# 729  9/9/2019 22:29:00        Alumni            < 25 th
#
#                  CaRek Pilihan  \
# 716  Sigit Puji Santosa (FTMD)
# 718  Sigit Puji Santosa (FTMD)
# 719  Sigit Puji Santosa (FTMD)
# 722  Sigit Puji Santosa (FTMD)
# 729  Sigit Puji Santosa (FTMD)
#
#                                   Alasan Memilih CaRek  \
# 716       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 718  Kapabilitas ybs utk memajukan riset dan indust...
# 719  Kapabilitas ybs utk memajukan riset dan indust...
# 722                                   Dosen pembimbing
# 729  Kapabilitas ybs utk memajukan riset dan indust...
#
#                                           Harapan Anda
# ...

# %%
df[df['CaRek Pilihan'] == 'Sigit Puji Santosa (FTMD)'].tail()
# Out:
#               Timestamp Kategori Anda Kategori Umur Anda  \
# 722   9/9/2019 11:23:27     Mahasiswa            < 25 th
# 729   9/9/2019 22:29:00        Alumni            < 25 th
# 749  9/10/2019 10:22:27        Alumni         25 - 40 th
# 921  9/14/2019 13:00:18         Dosen            > 40 th
# 949  9/15/2019 21:16:05         Dosen            > 40 th
#
#                  CaRek Pilihan  \
# 722  Sigit Puji Santosa (FTMD)
# 729  Sigit Puji Santosa (FTMD)
# 749  Sigit Puji Santosa (FTMD)
# 921  Sigit Puji Santosa (FTMD)
# 949  Sigit Puji Santosa (FTMD)
#
#                                   Alasan Memilih CaRek  \
# 722                                   Dosen pembimbing
# 729  Kapabilitas ybs utk memajukan riset dan indust...
# 749                          Keberhasilan dan prestasi
# 921  Tipe yg futuristik dan outside-the-box yg bisa...
# 949  Mendatangkan dana riset dan kerjasama eksterna...
#
#                                           Harapan Anda
# ...

# %%
import time

# %%
from datetime import date

# %%
today = date.today()

# %%
today
# Out:
# datetime.date(2019, 10, 15)

# %%
today == Pilihan1['Timestamp'][949]
# Out:
# False

# %%
test = date(2019,9,15)

# %%
test == Pilihan1['Timestamp'][949]
# Out:
# False

# %%
Pilihan1['Timestamp'][949]
# Out:
# '9/15/2019 21:16:05'

# %%
type(Pilihan1['Timestamp'][949])
# Out:
# str

# %%
type(test)
# Out:
# datetime.date

# %%
data= pd.to_datetime(Pilihan1['Timestamp'])

# %%
Pilihan1
# Out:
#               Timestamp Kategori Anda Kategori Umur Anda  \
# 78    9/1/2019 16:11:39        Alumni         25 - 40 th
# 115   9/1/2019 17:54:55        Alumni            > 40 th
# 145   9/1/2019 19:12:41         Dosen            > 40 th
# 175   9/1/2019 21:20:14         Dosen            > 40 th
# 179   9/1/2019 21:35:21        Alumni            > 40 th
# 183   9/1/2019 21:41:45        Alumni            > 40 th
# 189   9/1/2019 21:56:14        Alumni            > 40 th
# 190   9/1/2019 22:00:07        Alumni            > 40 th
# 199   9/1/2019 22:42:06        Alumni            > 40 th
# 201   9/1/2019 22:46:34        Alumni            > 40 th
# 202   9/1/2019 22:46:58        Alumni            > 40 th
# 223    9/2/2019 6:55:54         Dosen            > 40 th
# 239    9/2/2019 8:49:46        Alumni            > 40 th
# 259   9/2/2019 12:43:19          Umum            > 40 th
# 355    9/3/2019 0:32:43        Alumni            > 40 th
# ...

# %%
test == Pilihan1['Timestamp'][949]
# Out:
# False

# %%
(Pilihan1['Timestamp'] < today)&(Pilihan1['Timestamp'] > (today-pd.Timestamp(days=3))
# Out:
#   File "<ipython-input-36-c611407eaffc>", line 1
#     (Pilihan1['Timestamp'] < today)&(Pilihan1['Timestamp'] > (today-pd.Timestamp(days=3))
#                                                                                          ^
# SyntaxError: unexpected EOF while parsing

# %%
test3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-41c5985fc771> in <module>
# ----> 1 test3
#
# NameError: name 'test3' is not defined

# %%
today
# Out:
# datetime.date(2019, 10, 15)

# %%
timedelta = pd.
today-timedelta
# Out:
#   File "<ipython-input-39-4fc6e05e3355>", line 1
#     timedelta = pd.
#                    ^
# SyntaxError: invalid syntax

# %%
help timedelta
# Out:
#   File "<ipython-input-40-560a3f4d50a3>", line 1
#     help timedelta
#                  ^
# SyntaxError: invalid syntax

# %%
delay= pd.Timedelta(days=3)
delay1 = pd.to_datetime
# Out:
# Timedelta('3 days 00:00:00')

# %%
series =(Pilihan1['Timestamp'] < today)&(Pilihan1['Timestamp'] > (today-delay))
nilai = series.value_counts()
nilai
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-cba2766eec1d> in <module>
# ----> 1 series =(Pilihan1['Timestamp'] < today)&(Pilihan1['Timestamp'] > (today-delay))
#       2 nilai = series.value_counts()
#       3 nilai
#
# c:\users\thirza\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# c:\users\thirza\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
# ...

# %%
arr_days = nmp.array([[today, 0]])

 
i = 1
count=0
stamp= pd.to_datetime(Pilihan1['Timestamp'])

while i<5 :
    delay= today- pd.Timedelta(days=i)
    series = (stamp < today)&(stamp > delay)
    countmin = series.value_counts()[False]
    counttab = series.value_counts().sum()
    count= counttab-countmin
    arr_days = nmp.append(arr_days, [[delay,count]], axis = 0)
    i+=1
    
arr_days
# Out:
# c:\users\thirza\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   # Remove the CWD from sys.path while we load stuff.
# array([[datetime.date(2019, 10, 15), 0],
#        [datetime.date(2019, 10, 14), 0],
#        [datetime.date(2019, 10, 13), 0],
#        [datetime.date(2019, 10, 12), 0],
#        [datetime.date(2019, 10, 11), 0]], dtype=object)

# %%
arr_days[0,0] = date.__str__(arr_days[0,0])
arr_days[1,0] = date.__str__(arr_days[1,0])
arr_days[2,0] = date.__str__(arr_days[2,0])
arr_days[3,0] = date.__str__(arr_days[3,0])
arr_days[4,0] = date.__str__(arr_days[4,0])
arr_days
# Out:
# array([['2019-10-15', 0],
#        ['2019-10-14', 0],
#        ['2019-10-13', 0],
#        ['2019-10-12', 0],
#        ['2019-10-11', 0]], dtype=object)

# %%
Pilihan1
# Out:
#               Timestamp Kategori Anda Kategori Umur Anda  \
# 78    9/1/2019 16:11:39        Alumni         25 - 40 th
# 115   9/1/2019 17:54:55        Alumni            > 40 th
# 145   9/1/2019 19:12:41         Dosen            > 40 th
# 175   9/1/2019 21:20:14         Dosen            > 40 th
# 179   9/1/2019 21:35:21        Alumni            > 40 th
# 183   9/1/2019 21:41:45        Alumni            > 40 th
# 189   9/1/2019 21:56:14        Alumni            > 40 th
# 190   9/1/2019 22:00:07        Alumni            > 40 th
# 199   9/1/2019 22:42:06        Alumni            > 40 th
# 201   9/1/2019 22:46:34        Alumni            > 40 th
# 202   9/1/2019 22:46:58        Alumni            > 40 th
# 223    9/2/2019 6:55:54         Dosen            > 40 th
# 239    9/2/2019 8:49:46        Alumni            > 40 th
# 259   9/2/2019 12:43:19          Umum            > 40 th
# 355    9/3/2019 0:32:43        Alumni            > 40 th
# ...

# %%
delay= pd.Timedelta(days=3)
test22 = today-delay

# %%
test22
# Out:
# datetime.date(2019, 10, 12)

# %%
today
# Out:
# datetime.date(2019, 10, 15)

# %%
b, ax = plt.subplots()
b = plt.plot(arr_days[0:5,0], arr_days[0:5,1], 'go--')

ax.invert_xaxis()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...
