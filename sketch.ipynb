# %%
import matplotlib.pyplot as plt
import matplotlib.axis as ax
# %matplotlib inline
import pandas as pd
import numpy as np
from PIL import Image

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek-anon.csv'
df  = pd.read_csv(url)
df
# Out:
#                Timestamp     Kategori Anda Kategori Umur Anda  \
# 0       9/1/2019 7:42:45             Dosen         25 - 40 th
# 1       9/1/2019 7:47:58            Alumni         25 - 40 th
# 2       9/1/2019 7:49:32         Mahasiswa            < 25 th
# 3       9/1/2019 7:58:03             Dosen            > 40 th
# 4       9/1/2019 8:00:33         Mahasiswa            < 25 th
# ...                  ...               ...                ...
# 2024   9/25/2019 8:54:33              Umum         25 - 40 th
# 2025  9/26/2019 13:30:25  Pegawai / Tendik         25 - 40 th
# 2026  10/8/2019 14:28:00            Alumni         25 - 40 th
# 2027  10/8/2019 14:59:53            Alumni            > 40 th
# 2028  10/8/2019 15:10:17            Alumni            > 40 th
#
#                       CaRek Pilihan  \
# 0          Togar M Simatupang (SBM)
# 1     Suhono Harso Supangkat (STEI)
# 2          Bambang Riyanto T (STEI)
# 3          Togar M Simatupang (SBM)
# ...

# %%
df[df['CaRek Pilihan'] == 'Kadarsah Suryadi (FTI-TI)'].tail()
# Out:
#                Timestamp     Kategori Anda Kategori Umur Anda  \
# 1760    9/6/2019 9:23:04  Pegawai / Tendik         25 - 40 th
# 1822   9/8/2019 17:25:50              Umum            > 40 th
# 1852   9/11/2019 8:51:05             Dosen            > 40 th
# 2015  9/17/2019 22:27:18         Mahasiswa            < 25 th
# 2025  9/26/2019 13:30:25  Pegawai / Tendik         25 - 40 th
#
#                   CaRek Pilihan  \
# 1760  Kadarsah Suryadi (FTI-TI)
# 1822  Kadarsah Suryadi (FTI-TI)
# 1852  Kadarsah Suryadi (FTI-TI)
# 2015  Kadarsah Suryadi (FTI-TI)
# 2025  Kadarsah Suryadi (FTI-TI)
#
#                                    Alasan Memilih CaRek  \
# 1760  Program ybs utk peningkatan income dan kesejah...
# 1822                          Keberhasilan dan prestasi
# 1852  Program ybs utk peningkatan income dan kesejah...
# 2015       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 2025         Kecerdasan dan keberanian utk kemajuan ITB
#
# ...

# %%
Rektor1 = df[df['CaRek Pilihan'] == 'Kadarsah Suryadi (FTI-TI)']
Rektor1
# Out:
#                Timestamp     Kategori Anda Kategori Umur Anda  \
# 14     9/1/2019 12:26:02             Dosen            > 40 th
# 20     9/1/2019 13:37:04  Pegawai / Tendik         25 - 40 th
# 73     9/1/2019 14:51:19             Dosen            > 40 th
# 87     9/1/2019 15:07:55            Alumni         25 - 40 th
# 112    9/1/2019 15:51:24             Dosen            > 40 th
# ...                  ...               ...                ...
# 1760    9/6/2019 9:23:04  Pegawai / Tendik         25 - 40 th
# 1822   9/8/2019 17:25:50              Umum            > 40 th
# 1852   9/11/2019 8:51:05             Dosen            > 40 th
# 2015  9/17/2019 22:27:18         Mahasiswa            < 25 th
# 2025  9/26/2019 13:30:25  Pegawai / Tendik         25 - 40 th
#
#                   CaRek Pilihan  \
# 14    Kadarsah Suryadi (FTI-TI)
# 20    Kadarsah Suryadi (FTI-TI)
# 73    Kadarsah Suryadi (FTI-TI)
# 87    Kadarsah Suryadi (FTI-TI)
# 112   Kadarsah Suryadi (FTI-TI)
# ...

# %%
kat1 = Rektor1['Kategori Anda']

arr1 = np.array(kat1)
unique, counts = np.unique(arr1, return_counts=True)
list1 = dict(zip(unique, counts))
list1
#katanda = np.array({'Alumni', 'Dosen', 'Mahasiswa', 'Pegawai / Tendik', 'Umum'})
#list1['']
#arr2 = np.array({list1)
# Out:
# {'Alumni': 83,
#  'Dosen': 35,
#  'Mahasiswa': 57,
#  'Pegawai / Tendik': 82,
#  'Umum': 67}

# %%
name1 = ('A', 'P/T', 'U', 'M', 'D')
gra1 = kat1.value_counts().plot(kind='barh')

#gra1.set_yticks(name1)

#katanda = np.array({'Alumni', 'Dosen', 'Mahasiswa', 'Pegawai / Tendik', 'Umum'})
#plt.rcdefaults()
#fig, ax = plt.subplots()

#ax.barh(arr1, katanda, 3, align='center')
#ax.set_yticks(arr1)

plt.savefig('gra1.png', bbox_inches ='tight')

# %%
kat1.value_counts()
# Out:
# Alumni              83
# Pegawai / Tendik    82
# Umum                67
# Mahasiswa           57
# Dosen               35
# Name: Kategori Anda, dtype: int64

# %%
im1 = Image.open('gra1.png')

# %%
im1.size
# Out:
# (441, 248)

# %%
imback = Image.open('21330.jpg')

# %%
imback.size
# Out:
# (1477, 1108)

# %%
imback.paste(im1, (400,400))
imback
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1477x1108 at 0x11E0DCCD0>

# %%
imback
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1477x1108 at 0x11E0DCCD0>

# %%
help(plt.savefig)
# Out:
# Help on function savefig in module matplotlib.pyplot:
#
# savefig(*args, **kwargs)
#     Save the current figure.
#
#     Call signature::
#
#       savefig(fname, dpi=None, facecolor='w', edgecolor='w',
#               orientation='portrait', papertype=None, format=None,
#               transparent=False, bbox_inches=None, pad_inches=0.1,
#               frameon=None, metadata=None)
#
#     The output formats available depend on the backend being used.
#
#     Parameters
#     ----------
#
#     fname : str or PathLike or file-like object
#         A path, or a Python file-like object, or
#         possibly some backend-dependent object such as
#         `matplotlib.backends.backend_pdf.PdfPages`.
#
#         If *format* is not set, then the output format is inferred from
#         the extension of *fname*, if any, and from :rc:`savefig.format`
#         otherwise.  If *format* is set, it determines the output format.
#
# ...

# %%
#recent comments

# %%
Rektor1 = df[df['CaRek Pilihan'] == 'Kadarsah Suryadi (FTI-TI)']
alasan1 = Rektor1['Alasan Memilih CaRek']
alasan1.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-4d85a217f88c> in <module>
#       1 Rektor1 = df[df['CaRek Pilihan'] == 'Kadarsah Suryadi (FTI-TI)']
# ----> 2 alasan1 = df[Rektor1['Alasan Memilih CaRek']]
#       3 alasan1.tail()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
# ...

# %%
harapan1 = Rektor1['Harapan Anda']
arr3 = np.array(harapan1.tail())
arr3
# Out:
# array(['peningkatan income dan kesejahteraan dosen / pegawai', nan,
#        'Rektor ITB ke depan fapat menjadi good father keluarga besar ITB',
#        nan, nan], dtype=object)

# %%
harap1 = Rektor1.groupby(['Harapan Anda'])
harap1.set_index([pd.Index([1, 2,3, ..., 61])])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-fb62d04158dd> in <module>
#       1 harap1 = Rektor1.groupby(['Harapan Anda'])
# ----> 2 harap1.set_index([pd.Index([1, 2,3, ..., 61])])
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     561             return self[attr]
#     562         if hasattr(self.obj, attr):
# --> 563             return self._make_wrapper(attr)
#     564
#     565         raise AttributeError(
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     602                 "using the 'apply' method".format(kind, name, type(self).__name__)
#     603             )
# --> 604             raise AttributeError(msg)
#     605
#     606         self._set_group_selection()
#
# ...

# %%
val1 = kat1.value_counts()
val1
# Out:
# Alumni              83
# Pegawai / Tendik    82
# Umum                67
# Mahasiswa           57
# Dosen               35
# Name: Kategori Anda, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
#people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
#y_pos = np.arange(len(people))
#performance = 3 + 10 * np.random.rand(len(people))
#error = np.random.rand(len(people))

ax.barh(val1, 1, align='center')
#ax.barh(y_pos, performance, xerr=error, align='center')
#ax.set_yticks(y_pos)
#ax.invert_yaxis()  # labels read top-to-bottom
#ax.set_xlabel('Performance')
#ax.set_title('How fast do you want to go today?')

plt.show()

# %%
help(plt.barh)
# Out:
# Help on function barh in module matplotlib.pyplot:
#
# barh(y, width, height=0.8, left=None, *, align='center', **kwargs)
#     Make a horizontal bar plot.
#
#     The bars are positioned at *y* with the given *align*\ment. Their
#     dimensions are given by *width* and *height*. The horizontal baseline
#     is *left* (default 0).
#
#     Each of *y*, *width*, *height*, and *left* may either be a scalar
#     applying to all bars, or it may be a sequence of length N providing a
#     separate value for each bar.
#
#     Parameters
#     ----------
#     y : scalar or array-like
#         The y coordinates of the bars. See also *align* for the
#         alignment of the bars to the coordinates.
#
#     width : scalar or array-like
#         The width(s) of the bars.
#
#     height : sequence of scalars, optional, default: 0.8
#         The heights of the bars.
#
#     left : sequence of scalars
#         The x coordinates of the left sides of the bars (default: 0).
#
# ...

# %%
gra1

# %%
help(plt.savefig)
# Out:
# Help on function savefig in module matplotlib.pyplot:
#
# savefig(*args, **kwargs)
#     Save the current figure.
#
#     Call signature::
#
#       savefig(fname, dpi=None, facecolor='w', edgecolor='w',
#               orientation='portrait', papertype=None, format=None,
#               transparent=False, bbox_inches=None, pad_inches=0.1,
#               frameon=None, metadata=None)
#
#     The output formats available depend on the backend being used.
#
#     Parameters
#     ----------
#
#     fname : str or PathLike or file-like object
#         A path, or a Python file-like object, or
#         possibly some backend-dependent object such as
#         `matplotlib.backends.backend_pdf.PdfPages`.
#
#         If *format* is not set, then the output format is inferred from
#         the extension of *fname*, if any, and from :rc:`savefig.format`
#         otherwise.  If *format* is set, it determines the output format.
#
# ...

# %%
harapan1 = Rektor1.tail()[['Kategori Anda','Harapan Anda']]
harapan1
# Out:
#          Kategori Anda                                       Harapan Anda
# 1760  Pegawai / Tendik  peningkatan income dan kesejahteraan dosen / p...
# 1822              Umum                                                NaN
# 1852             Dosen  Rektor ITB ke depan fapat menjadi good father ...
# 2015         Mahasiswa                                                NaN
# 2025  Pegawai / Tendik                                                NaN

# %%
arrhar = np.array(harapan1)

# %%
arrhar
# Out:
# array([['Pegawai / Tendik',
#         'peningkatan income dan kesejahteraan dosen / pegawai'],
#        ['Umum', nan],
#        ['Dosen',
#         'Rektor ITB ke depan fapat menjadi good father keluarga besar ITB'],
#        ['Mahasiswa', nan],
#        ['Pegawai / Tendik', nan]], dtype=object)

# %%
type(arrhar[0,1])
# Out:
# str

# %%
Image.open('imtest.png')

# %%
gam1 = Image.open('imtest.png')

# %%
from PIL import ImageFont

# %%
font = ImageFont.truetype("Philosopher-Italic.ttf", 8)

# %%
help(ImageFont.truetype)

# %%
counttab = counttab = harapan1.value_counts().sum()
s = pd.Series([1,2,3,4,...,counttab])
Rektor1.set_index([s])
# Out:
#   File "<ipython-input-31-e201356d1dcd>", line 2
#     s = pd.Series([1,2,3,4...,counttab])
#                             ^
# SyntaxError: invalid syntax

# %%
from PIL import ImageDraw

# %%
draw = ImageDraw.Draw(gam1)

# %%
draw.text((231, 123),arrhar[0,1],(32,2,3),font=font)
draw.text((140, 123),arrhar[0,0],(32,2,3),font=font)

# %%
gam1.save('sample-out.png')

# %%
gam1

# %%
help(ImageDraw.Draw.text)

# %%
arr10 = np.zeros(5,5)

# %%
gam2 = Image.open('Calon Rektor ITB.png')

# %%
draw = ImageDraw.Draw(gam2)

# %%
gam2.size

# %%
font1 = ImageFont.truetype("Philosopher-Italic.ttf", 30)
font2 = ImageFont.truetype("Philosopher-Italic.ttf", 25)
draw.text((800, 1835),arrhar[0,1],(32,2,3),font=font2)
draw.text((250, 1835),arrhar[0,0],(32,2,3),font=font1)
draw.text((800, 1635),arrhar[2,1],(32,2,3),font=font2)
draw.text((250, 1635),arrhar[2,0],(32,2,3),font=font1)
gam2.save('present1.png')
gam2

# %%
harapan1 = Rektor1['Harapan Anda'] != ''

# %%
harapan1
# Out:
# 14      True
# 20      True
# 73      True
# 87      True
# 112     True
#         ...
# 1760    True
# 1822    True
# 1852    True
# 2015    True
# 2025    True
# Name: Harapan Anda, Length: 324, dtype: bool

# %%
i = 1
arr_har1 = np.array(['Umum', 'Umum'])
counttab = harapan1.value_counts().sum()
j = counttab
while i<5 :
    while j!=-1:
        if (Rektor1['Harapan Anda'][j] != NaN):
            arr_har1 = np.append(arr_har1, [[delay,count]], axis = 0)
            i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-db921b4d98a2> in <module>
#       5 while i<5 :
#       6     while j!=-1:
# ----> 7         if (Rektor1['Harapan Anda'][j] != NaN):
#       8             arr_har1 = np.append(arr_har1, [[delay,count]], axis = 0)
#       9             i+=1
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
# ...

# %%
Rektor1[['Kategori Anda','Harapan Anda']].tail()
# Out:
#          Kategori Anda                                       Harapan Anda
# 1760  Pegawai / Tendik  peningkatan income dan kesejahteraan dosen / p...
# 1822              Umum                                                NaN
# 1852             Dosen  Rektor ITB ke depan fapat menjadi good father ...
# 2015         Mahasiswa                                                NaN
# 2025  Pegawai / Tendik                                                NaN

# %%
type(arrhar[0,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-8836379076bc> in <module>
# ----> 1 type(arrhar[0,1])
#
# NameError: name 'arrhar' is not defined

# %%
s = pd.Series([1])
last = Rektor1['CaRek Pilihan'].tail(1)
thelast = np.array(last)
thelast[0]
# Out:
# 'Kadarsah Suryadi (FTI-TI)'
