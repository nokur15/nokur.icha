# %%
import matplotlib.pyplot as plt
import matplotlib.axis as ax
# %matplotlib inline
import pandas as pd
import numpy as np
from PIL import Image

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek-anon.csv'
df  = pd.read_csv(url)
df
# Out:
#                Timestamp     Kategori Anda Kategori Umur Anda  \
# 0       9/1/2019 7:42:45             Dosen         25 - 40 th
# 1       9/1/2019 7:47:58            Alumni         25 - 40 th
# 2       9/1/2019 7:49:32         Mahasiswa            < 25 th
# 3       9/1/2019 7:58:03             Dosen            > 40 th
# 4       9/1/2019 8:00:33         Mahasiswa            < 25 th
# ...                  ...               ...                ...
# 2024   9/25/2019 8:54:33              Umum         25 - 40 th
# 2025  9/26/2019 13:30:25  Pegawai / Tendik         25 - 40 th
# 2026  10/8/2019 14:28:00            Alumni         25 - 40 th
# 2027  10/8/2019 14:59:53            Alumni            > 40 th
# 2028  10/8/2019 15:10:17            Alumni            > 40 th
#
#                       CaRek Pilihan  \
# 0          Togar M Simatupang (SBM)
# 1     Suhono Harso Supangkat (STEI)
# 2          Bambang Riyanto T (STEI)
# 3          Togar M Simatupang (SBM)
# ...

# %%
df[df['CaRek Pilihan'] == 'Kadarsah Suryadi (FTI-TI)'].tail()
# Out:
#                Timestamp     Kategori Anda Kategori Umur Anda  \
# 1760    9/6/2019 9:23:04  Pegawai / Tendik         25 - 40 th
# 1822   9/8/2019 17:25:50              Umum            > 40 th
# 1852   9/11/2019 8:51:05             Dosen            > 40 th
# 2015  9/17/2019 22:27:18         Mahasiswa            < 25 th
# 2025  9/26/2019 13:30:25  Pegawai / Tendik         25 - 40 th
#
#                   CaRek Pilihan  \
# 1760  Kadarsah Suryadi (FTI-TI)
# 1822  Kadarsah Suryadi (FTI-TI)
# 1852  Kadarsah Suryadi (FTI-TI)
# 2015  Kadarsah Suryadi (FTI-TI)
# 2025  Kadarsah Suryadi (FTI-TI)
#
#                                    Alasan Memilih CaRek  \
# 1760  Program ybs utk peningkatan income dan kesejah...
# 1822                          Keberhasilan dan prestasi
# 1852  Program ybs utk peningkatan income dan kesejah...
# 2015       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 2025         Kecerdasan dan keberanian utk kemajuan ITB
#
# ...

# %%
Rektor1 = df[df['CaRek Pilihan'] == 'Kadarsah Suryadi (FTI-TI)']

# %%
kat1 = Rektor1['Kategori Anda']
kat1
# Out:
# 14                 Dosen
# 20      Pegawai / Tendik
# 73                 Dosen
# 87                Alumni
# 112                Dosen
#               ...
# 1760    Pegawai / Tendik
# 1822                Umum
# 1852               Dosen
# 2015           Mahasiswa
# 2025    Pegawai / Tendik
# Name: Kategori Anda, Length: 324, dtype: object

# %%
kat1.value_counts()
# Out:
# Alumni              83
# Pegawai / Tendik    82
# Umum                67
# Mahasiswa           57
# Dosen               35
# Name: Kategori Anda, dtype: int64

# %%
gra1 = kat1.value_counts().plot(kind='bar')
gra1
plt.savefig('gra1.png')

# %%
im1 = Image.open('gra1.png')

# %%
im1.size
# Out:
# (432, 288)

# %%
imback = Image.open('21330.jpg')

# %%
imback.size
# Out:
# (1477, 1108)

# %%
imback.paste(im1, (400,400))
imback
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1477x1108 at 0x10E4645D0>

# %%
imback
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1477x1108 at 0x10E4240D0>

# %%
help(plt.savefig)
# Out:
# Help on function savefig in module matplotlib.pyplot:
#
# savefig(*args, **kwargs)
#     Save the current figure.
#
#     Call signature::
#
#       savefig(fname, dpi=None, facecolor='w', edgecolor='w',
#               orientation='portrait', papertype=None, format=None,
#               transparent=False, bbox_inches=None, pad_inches=0.1,
#               frameon=None, metadata=None)
#
#     The output formats available depend on the backend being used.
#
#     Parameters
#     ----------
#
#     fname : str or PathLike or file-like object
#         A path, or a Python file-like object, or
#         possibly some backend-dependent object such as
#         `matplotlib.backends.backend_pdf.PdfPages`.
#
#         If *format* is not set, then the output format is inferred from
#         the extension of *fname*, if any, and from :rc:`savefig.format`
#         otherwise.  If *format* is set, it determines the output format.
#
# ...

# %%
#version 2

# %%
Rektor1 = df[df['CaRek Pilihan'] == 'Kadarsah Suryadi (FTI-TI)']
alasan1 = Rektor1['Alasan Memilih CaRek']
alasan1.tail()
# Out:
# 1760    Program ybs utk peningkatan income dan kesejah...
# 1822                            Keberhasilan dan prestasi
# 1852    Program ybs utk peningkatan income dan kesejah...
# 2015         Sesuai dengan kriteria kekinian (Rektor 4.0)
# 2025           Kecerdasan dan keberanian utk kemajuan ITB
# Name: Alasan Memilih CaRek, dtype: object

# %%
harapan1 = Rektor1['Harapan Anda']
harapan1.tail()
# Out:
# 1760    peningkatan income dan kesejahteraan dosen / p...
# 1822                                                  NaN
# 1852    Rektor ITB ke depan fapat menjadi good father ...
# 2015                                                  NaN
# 2025                                                  NaN
# Name: Harapan Anda, dtype: object

# %%
harap1 = Rektor1.groupby(['Harapan Anda'])
harap1.tail()
# Out:
#                Timestamp     Kategori Anda Kategori Umur Anda  \
# 112    9/1/2019 15:51:24             Dosen            > 40 th
# 184    9/1/2019 18:21:08         Mahasiswa            > 40 th
# 208    9/1/2019 20:56:24              Umum            > 40 th
# 210    9/1/2019 20:59:31              Umum            > 40 th
# 212    9/1/2019 21:01:04  Pegawai / Tendik            > 40 th
# ...                  ...               ...                ...
# 1760    9/6/2019 9:23:04  Pegawai / Tendik         25 - 40 th
# 1822   9/8/2019 17:25:50              Umum            > 40 th
# 1852   9/11/2019 8:51:05             Dosen            > 40 th
# 2015  9/17/2019 22:27:18         Mahasiswa            < 25 th
# 2025  9/26/2019 13:30:25  Pegawai / Tendik         25 - 40 th
#
#                   CaRek Pilihan  \
# 112   Kadarsah Suryadi (FTI-TI)
# 184   Kadarsah Suryadi (FTI-TI)
# 208   Kadarsah Suryadi (FTI-TI)
# 210   Kadarsah Suryadi (FTI-TI)
# 212   Kadarsah Suryadi (FTI-TI)
# ...

# %%
val1 = kat1.value_counts()
val1
# Out:
# Alumni              83
# Pegawai / Tendik    82
# Umum                67
# Mahasiswa           57
# Dosen               35
# Name: Kategori Anda, dtype: int64

# %%
gra2 = plt.bar(val1, 200)
plt.savefig('gra2.png')
